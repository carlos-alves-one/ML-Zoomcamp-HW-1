# %% [markdown]
# <a href="https://colab.research.google.com/github/carlos-alves-one/-Zoomcamp-Homework-1/blob/main/Zoomcamp_Homework_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Machine Learning ZoomCamp - Homework 1
# **Author.....: Carlos Manuel de Oliveira Alves**<br>
# **Created...: 05/08/2022**

# %%
# import libraries Numpy and Pandas
import numpy as np
import pandas as pd

# %% [markdown]
# ##Question 1
#
# **What's the version of NumPy that you installed?**

# %%
np.__version__
# Out:
# '1.21.6'

# %%
# getting the data for the homework
# !wget https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/chapter-02-car-price/data.csv
# Out:
# --2022-09-05 21:00:32--  https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/chapter-02-car-price/data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1475504 (1.4M) [text/plain]
# Saving to: ‘data.csv’
#
# data.csv            100%[===================>]   1.41M  --.-KB/s    in 0.008s
#
# 2022-09-05 21:00:32 (181 MB/s) - ‘data.csv’ saved [1475504/1475504]

# %%
# read and save the data from the homework
df = pd.read_csv('data.csv')
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %% [markdown]
# ##Question 2
#
# **How many records are in the dataset?**

# %%
len(df)
# Out:
# 11914

# %% [markdown]
# ##Question 3
#
# **Who are the most popular car manufacturers (top-3) according to the dataset?**

# %%
popularCar = df.groupby('Make').count().sort_values('Popularity',ascending=False)
popularCar
# Out:
#                Model  Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# Make
# Chevrolet       1123  1123              1123       1117              1121
# Ford             881   881               881        868               881
# Volkswagen       809   809               809        809               805
# Toyota           746   746               746        744               745
# Dodge            626   626               626        626               626
# Nissan           558   558               558        548               558
# GMC              515   515               515        515               515
# Honda            449   449               449        447               449
# Mazda            423   423               423        423               403
# Cadillac         397   397               397        397               397
# Mercedes-Benz    353   353               353        352               353
# Suzuki           351   351               348        351               351
# ...

# %% [markdown]
# **Chevrolet, Volkswagen, Toyota**

# %% [markdown]
# ##Question 4
#
# **What's the number of unique Audi car models in the dataset?**

# %%
audiModels = df[df.Make == 'Audi']['Model'].unique()
audiModels
# Out:
# array(['100', '200', '80', '90', 'A3', 'A4 allroad', 'A4', 'A5', 'A6',
#        'A7', 'A8', 'allroad quattro', 'allroad', 'Cabriolet', 'Coupe',
#        'Q3', 'Q5', 'Q7', 'R8', 'RS 4', 'RS 5', 'RS 6', 'RS 7', 'S3', 'S4',
#        'S5', 'S6', 'S7', 'S8', 'SQ5', 'TT RS', 'TT', 'TTS', 'V8'],
#       dtype=object)

# %%
len(audiModels)
# Out:
# 34

# %% [markdown]
# ##Question 5
#
# **How many columns in the dataset have missing values?**

# %%
missingValues = df.isnull().sum()
missingValues
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
np.count_nonzero(missingValues)
# Out:
# 5

# %% [markdown]
# ##Question 6.1
#
# **Find the median value of "Engine Cylinders" column in the dataset.**

# %%
medianEngine = df['Engine Cylinders'].median()
medianEngine
# Out:
# 6.0

# %% [markdown]
# ##Question 6.2
#
# **Next, calculate the most frequent value of the same "Engine Cylinders".**

# %%
freqEngine = df['Engine Cylinders'].value_counts()
freqEngine
# Out:
# 4.0     4752
# 6.0     4489
# 8.0     2031
# 12.0     230
# 5.0      225
# 10.0      68
# 0.0       56
# 3.0       30
# 16.0       3
# Name: Engine Cylinders, dtype: int64

# %%
x = freqEngine.keys()[0]
x
# Out:
# 4.0

# %% [markdown]
# ##Question 6.3
#
# **Use the fillna method to fill the missing values in "Engine Cylinders" with the most frequent value from the previous step.**

# %%
newMedian = df['Engine Cylinders'].fillna(x).median()
newMedian
# Out:
# 6.0

# %% [markdown]
# ##Question 6.4
#
# **Now, calculate the median value of "Engine Cylinders" once again.**

# %%
newMedian2 = df['Engine Cylinders'].median()
newMedian2
# Out:
# 6.0

# %% [markdown]
# ##Question 7.1
#
# **Select all the "Lotus" cars from the dataset.**

# %%
lotusCars = df[df.Make == 'Lotus']
lotusCars
# Out:
#        Make      Model  Year                Engine Fuel Type  Engine HP  \
# 3912  Lotus      Elise  2009     premium unleaded (required)      189.0
# 3913  Lotus      Elise  2009     premium unleaded (required)      218.0
# 3914  Lotus      Elise  2009     premium unleaded (required)      189.0
# 3915  Lotus      Elise  2010     premium unleaded (required)      189.0
# 3916  Lotus      Elise  2010     premium unleaded (required)      218.0
# 3917  Lotus      Elise  2011     premium unleaded (required)      189.0
# 3918  Lotus      Elise  2011     premium unleaded (required)      217.0
# 3919  Lotus      Elise  2011     premium unleaded (required)      217.0
# 4216  Lotus     Esprit  2002     premium unleaded (required)      350.0
# 4217  Lotus     Esprit  2003     premium unleaded (required)      350.0
# 4218  Lotus     Esprit  2004     premium unleaded (required)      350.0
# 4257  Lotus  Evora 400  2017     premium unleaded (required)      400.0
# ...

# %% [markdown]
# ##Question 7.2
#
# **Select only columns "Engine HP", "Engine Cylinders".**

# %%
lotusCars = df[df.Make == 'Lotus'][['Engine HP','Engine Cylinders']]
lotusCars
# Out:
#       Engine HP  Engine Cylinders
# 3912      189.0               4.0
# 3913      218.0               4.0
# 3914      189.0               4.0
# 3915      189.0               4.0
# 3916      218.0               4.0
# 3917      189.0               4.0
# 3918      217.0               4.0
# 3919      217.0               4.0
# 4216      350.0               8.0
# 4217      350.0               8.0
# 4218      350.0               8.0
# 4257      400.0               6.0
# 4258      400.0               6.0
# 4259      276.0               6.0
# 4260      276.0               6.0
# 4261      276.0               6.0
# 4262      345.0               6.0
# 4263      345.0               6.0
# 4264      276.0               6.0
# 4265      345.0               6.0
# 4266      276.0               6.0
# 4267      345.0               6.0
# 4268      276.0               6.0
# 4292      257.0               4.0
# 4293      240.0               4.0
# 4294      240.0               4.0
# ...

# %% [markdown]
# ##Question 7.3
#
# **Now drop all duplicated rows using drop_duplicates method (you should get a dataframe with 9 rows).**

# %%
lotusCars = df[df.Make == 'Lotus'][['Engine HP','Engine Cylinders']].drop_duplicates()
lotusCars
# Out:
#       Engine HP  Engine Cylinders
# 3912      189.0               4.0
# 3913      218.0               4.0
# 3918      217.0               4.0
# 4216      350.0               8.0
# 4257      400.0               6.0
# 4259      276.0               6.0
# 4262      345.0               6.0
# 4292      257.0               4.0
# 4293      240.0               4.0
